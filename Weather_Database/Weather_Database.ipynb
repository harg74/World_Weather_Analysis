# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from config import weather_api_key

# %%
#Create a set of random lats y lngs combinations

lats=np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
cities=[]

for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
#create URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial"

# %%
city_data=[]

# Import the datetime module from the datetime library.
from datetime import datetime

# Print the beginning of the logging
print('Beginning Data Retreival')
print("-----------------------------")

#create counters

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
        #print(f'Set count{set_count}') see how changes the set_count
    
    # Create endpoint URL with each city. city. 
    #replace is used to replace the s pace blanks to the cities that have 2 words
    #city_url = url + '&APPID=' + weather_api_key + '&q=' + city.replace(' ','+')
    city_url=f'{url}&APPID={weather_api_key}&q={city.replace(" ","+")}'
    #print(f'Set count{set_count}') see how the set works
    #print(f'Record count{record_count}') see how the record works

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description=city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          'Current Description':weather_description})

# If an error is experienced, skip the city.
# the skipping cites are due to that we are generating random nums (lats and lngs)
# and may exists in citypy, since we are passing them to citypy
# but may not exists in Open Weather Map API.
    except:
        print("City not found. Skipping...", city)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(len(city_data))
# Out:
# Beginning Data Retreival
# -----------------------------
# Processing Record 1 of Set 1 | carupano
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | manjeshwar
# Processing Record 6 of Set 1 | nuuk
# Processing Record 7 of Set 1 | haines junction
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | maghama
# City not found. Skipping... maghama
# Processing Record 10 of Set 1 | berlevag
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping... belushya guba
# Processing Record 13 of Set 1 | bambous virieux
# Processing Record 14 of Set 1 | vestmannaeyjar
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | chinsali
# Processing Record 17 of Set 1 | brae
# Processing Record 18 of Set 1 | dothan
# Processing Record 19 of Set 1 | sinnamary
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | medicine hat
# Processing Record 24 of Set 1 | pangkalanbuun
# Processing Record 25 of Set 1 | penjamo
# Processing Record 26 of Set 1 | eureka
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | bani
# Processing Record 29 of Set 1 | arrecife
# Processing Record 30 of Set 1 | alcacer do sal
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | karratha
# Processing Record 33 of Set 1 | touros
# Processing Record 34 of Set 1 | siguiri
# Processing Record 35 of Set 1 | isabela
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | isangel
# Processing Record 39 of Set 1 | saint-philippe
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | ascension
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | ulaanbaatar
# Processing Record 44 of Set 1 | santa cecilia
# Processing Record 45 of Set 1 | port hedland
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | vallenar
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | port hardy
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | dakar
# Processing Record 5 of Set 2 | sao joao da barra
# Processing Record 6 of Set 2 | gravelbourg
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping... illoqqortoormiut
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | we
# City not found. Skipping... we
# Processing Record 11 of Set 2 | akil
# Processing Record 12 of Set 2 | boo
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | oranjemund
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | grand river south east
# City not found. Skipping... grand river south east
# Processing Record 18 of Set 2 | arzgir
# Processing Record 19 of Set 2 | santa fe
# Processing Record 20 of Set 2 | samalaeulu
# City not found. Skipping... samalaeulu
# Processing Record 21 of Set 2 | jalu
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | yamada
# Processing Record 25 of Set 2 | kloulklubed
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | puerto escondido
# Processing Record 28 of Set 2 | te anau
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | havoysund
# Processing Record 31 of Set 2 | bonthe
# Processing Record 32 of Set 2 | basco
# Processing Record 33 of Set 2 | comodoro rivadavia
# Processing Record 34 of Set 2 | srednekolymsk
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | turukhansk
# Processing Record 37 of Set 2 | beihai
# Processing Record 38 of Set 2 | rocha
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | fairbanks
# Processing Record 42 of Set 2 | katsiveli
# City not found. Skipping... katsiveli
# Processing Record 43 of Set 2 | baculin
# Processing Record 44 of Set 2 | neuquen
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping... taolanaro
# Processing Record 46 of Set 2 | khatanga
# Processing Record 47 of Set 2 | riberalta
# Processing Record 48 of Set 2 | kawalu
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | ambilobe
# Processing Record 2 of Set 3 | narsaq
# Processing Record 3 of Set 3 | strezhevoy
# Processing Record 4 of Set 3 | port moresby
# Processing Record 5 of Set 3 | itoman
# Processing Record 6 of Set 3 | whitehaven
# Processing Record 7 of Set 3 | dera bugti
# Processing Record 8 of Set 3 | bahar
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | mataura
# Processing Record 11 of Set 3 | henties bay
# Processing Record 12 of Set 3 | sioux lookout
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | utiroa
# City not found. Skipping... utiroa
# Processing Record 16 of Set 3 | saint-joseph
# Processing Record 17 of Set 3 | shingu
# Processing Record 18 of Set 3 | pangai
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | aflu
# City not found. Skipping... aflu
# Processing Record 21 of Set 3 | paamiut
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | lavrentiya
# Processing Record 24 of Set 3 | clyde river
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | kotelnich
# Processing Record 27 of Set 3 | luderitz
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping... palabuhanratu
# Processing Record 29 of Set 3 | bluff
# Processing Record 30 of Set 3 | torquay
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | alofi
# Processing Record 34 of Set 3 | sibolga
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | jumla
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | verkhoyansk
# Processing Record 39 of Set 3 | grootfontein
# Processing Record 40 of Set 3 | mar del plata
# Processing Record 41 of Set 3 | hualmay
# Processing Record 42 of Set 3 | evensk
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | nago
# Processing Record 45 of Set 3 | norwich
# Processing Record 46 of Set 3 | santa maria
# Processing Record 47 of Set 3 | leningradskiy
# Processing Record 48 of Set 3 | atuona
# Processing Record 49 of Set 3 | acapulco
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | samana
# Processing Record 2 of Set 4 | walvis bay
# Processing Record 3 of Set 4 | barawe
# City not found. Skipping... barawe
# Processing Record 4 of Set 4 | dawei
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | marystown
# Processing Record 7 of Set 4 | roverud
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | hobyo
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping... sentyabrskiy
# Processing Record 13 of Set 4 | coahuayana
# Processing Record 14 of Set 4 | new norfolk
# Processing Record 15 of Set 4 | tengushevo
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping... nizhneyansk
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | marv dasht
# City not found. Skipping... marv dasht
# Processing Record 19 of Set 4 | oussouye
# Processing Record 20 of Set 4 | hermanus
# Processing Record 21 of Set 4 | moerai
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | maksatikha
# Processing Record 24 of Set 4 | calbuco
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | warrnambool
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | ahuimanu
# Processing Record 29 of Set 4 | morgantown
# Processing Record 30 of Set 4 | whitehorse
# Processing Record 31 of Set 4 | bida
# Processing Record 32 of Set 4 | konya
# Processing Record 33 of Set 4 | cockburn harbour
# City not found. Skipping... cockburn harbour
# Processing Record 34 of Set 4 | mount isa
# Processing Record 35 of Set 4 | opotiki
# Processing Record 36 of Set 4 | saskylakh
# Processing Record 37 of Set 4 | luanda
# Processing Record 38 of Set 4 | grand gaube
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping... attawapiskat
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | mitsamiouli
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping... barentsburg
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | yar-sale
# Processing Record 45 of Set 4 | dodge city
# Processing Record 46 of Set 4 | cascais
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | kahului
# Processing Record 50 of Set 4 | the valley
# Processing Record 1 of Set 5 | ancud
# Processing Record 2 of Set 5 | lisakovsk
# Processing Record 3 of Set 5 | estevan
# Processing Record 4 of Set 5 | richards bay
# Processing Record 5 of Set 5 | uwayl
# City not found. Skipping... uwayl
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping... mys shmidta
# Processing Record 10 of Set 5 | bilibino
# Processing Record 11 of Set 5 | greystones
# Processing Record 12 of Set 5 | praia da vitoria
# Processing Record 13 of Set 5 | moranbah
# Processing Record 14 of Set 5 | borovoy
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | amapa
# Processing Record 17 of Set 5 | arman
# Processing Record 18 of Set 5 | victoria
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | toktogul
# Processing Record 22 of Set 5 | kathu
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | buchanan
# Processing Record 25 of Set 5 | concepcion del oro
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | mullaitivu
# City not found. Skipping... mullaitivu
# Processing Record 28 of Set 5 | port macquarie
# Processing Record 29 of Set 5 | tailai
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | vardo
# Processing Record 32 of Set 5 | khandyga
# Processing Record 33 of Set 5 | belmonte
# Processing Record 34 of Set 5 | vaitupu
# City not found. Skipping... vaitupu
# Processing Record 35 of Set 5 | marienburg
# Processing Record 36 of Set 5 | malakal
# Processing Record 37 of Set 5 | kamenka
# Processing Record 38 of Set 5 | talnakh
# Processing Record 39 of Set 5 | boende
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | opuwo
# Processing Record 42 of Set 5 | mier
# Processing Record 43 of Set 5 | severo-yeniseyskiy
# Processing Record 44 of Set 5 | sinkat
# City not found. Skipping... sinkat
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | conceicao do araguaia
# Processing Record 47 of Set 5 | kuche
# City not found. Skipping... kuche
# Processing Record 48 of Set 5 | auki
# Processing Record 49 of Set 5 | coos bay
# Processing Record 50 of Set 5 | amderma
# City not found. Skipping... amderma
# Processing Record 1 of Set 6 | tautira
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | nabire
# Processing Record 4 of Set 6 | turayf
# Processing Record 5 of Set 6 | provideniya
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | lebu
# Processing Record 8 of Set 6 | murgab
# Processing Record 9 of Set 6 | samusu
# City not found. Skipping... samusu
# Processing Record 10 of Set 6 | banepa
# Processing Record 11 of Set 6 | tsihombe
# City not found. Skipping... tsihombe
# Processing Record 12 of Set 6 | nicoya
# Processing Record 13 of Set 6 | prince rupert
# Processing Record 14 of Set 6 | buraydah
# Processing Record 15 of Set 6 | banda aceh
# Processing Record 16 of Set 6 | rodas
# Processing Record 17 of Set 6 | lishui
# Processing Record 18 of Set 6 | half moon bay
# Processing Record 19 of Set 6 | henzada
# City not found. Skipping... henzada
# Processing Record 20 of Set 6 | jinka
# Processing Record 21 of Set 6 | jishou
# Processing Record 22 of Set 6 | asayita
# City not found. Skipping... asayita
# Processing Record 23 of Set 6 | iguatu
# Processing Record 24 of Set 6 | cayenne
# Processing Record 25 of Set 6 | zeya
# Processing Record 26 of Set 6 | sorland
# Processing Record 27 of Set 6 | saint anthony
# Processing Record 28 of Set 6 | flin flon
# Processing Record 29 of Set 6 | norman wells
# Processing Record 30 of Set 6 | asau
# Processing Record 31 of Set 6 | rio gallegos
# Processing Record 32 of Set 6 | verkhnevilyuysk
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | tazovskiy
# Processing Record 35 of Set 6 | velikie luki
# City not found. Skipping... velikie luki
# Processing Record 36 of Set 6 | paracuru
# Processing Record 37 of Set 6 | astoria
# Processing Record 38 of Set 6 | tessalit
# Processing Record 39 of Set 6 | lensk
# Processing Record 40 of Set 6 | seymchan
# Processing Record 41 of Set 6 | toliary
# City not found. Skipping... toliary
# Processing Record 42 of Set 6 | bismarck
# Processing Record 43 of Set 6 | nyurba
# Processing Record 44 of Set 6 | umm lajj
# Processing Record 45 of Set 6 | rafaela
# Processing Record 46 of Set 6 | dingzhou
# Processing Record 47 of Set 6 | susanville
# Processing Record 48 of Set 6 | north bend
# Processing Record 49 of Set 6 | alakurtti
# Processing Record 50 of Set 6 | milkovo
# Processing Record 1 of Set 7 | sunndalsora
# Processing Record 2 of Set 7 | pombia
# Processing Record 3 of Set 7 | poum
# Processing Record 4 of Set 7 | hovd
# Processing Record 5 of Set 7 | moron
# Processing Record 6 of Set 7 | quatre cocos
# Processing Record 7 of Set 7 | raudeberg
# Processing Record 8 of Set 7 | bonavista
# Processing Record 9 of Set 7 | ambon
# Processing Record 10 of Set 7 | kidal
# Processing Record 11 of Set 7 | sitka
# Processing Record 12 of Set 7 | one hundred mile house
# City not found. Skipping... one hundred mile house
# Processing Record 13 of Set 7 | andra
# Processing Record 14 of Set 7 | vao
# Processing Record 15 of Set 7 | flinders
# Processing Record 16 of Set 7 | karakendzha
# City not found. Skipping... karakendzha
# Processing Record 17 of Set 7 | oriximina
# Processing Record 18 of Set 7 | beloha
# Processing Record 19 of Set 7 | louisbourg
# City not found. Skipping... louisbourg
# Processing Record 20 of Set 7 | le port
# Processing Record 21 of Set 7 | mahebourg
# Processing Record 22 of Set 7 | sao filipe
# Processing Record 23 of Set 7 | mackay
# Processing Record 24 of Set 7 | yulara
# Processing Record 25 of Set 7 | muravlenko
# Processing Record 26 of Set 7 | huron
# Processing Record 27 of Set 7 | shahreza
# Processing Record 28 of Set 7 | cabedelo
# Processing Record 29 of Set 7 | puerto colombia
# Processing Record 30 of Set 7 | sao jose da coroa grande
# Processing Record 31 of Set 7 | ordzhonikidze
# Processing Record 32 of Set 7 | buguias
# Processing Record 33 of Set 7 | huarmey
# Processing Record 34 of Set 7 | ixtapa
# Processing Record 35 of Set 7 | pineville
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | nogliki
# Processing Record 38 of Set 7 | powell river
# Processing Record 39 of Set 7 | jinchengjiang
# City not found. Skipping... jinchengjiang
# Processing Record 40 of Set 7 | irtyshskiy
# Processing Record 41 of Set 7 | puerto del rosario
# Processing Record 42 of Set 7 | krabi
# Processing Record 43 of Set 7 | nhulunbuy
# Processing Record 44 of Set 7 | ostrovnoy
# Processing Record 45 of Set 7 | bull savanna
# Processing Record 46 of Set 7 | fort nelson
# Processing Record 47 of Set 7 | westpunt
# City not found. Skipping... westpunt
# Processing Record 48 of Set 7 | bacuit
# City not found. Skipping... bacuit
# Processing Record 49 of Set 7 | simao
# Processing Record 50 of Set 7 | tongren
# Processing Record 1 of Set 8 | capitao poco
# Processing Record 2 of Set 8 | san cristobal
# Processing Record 3 of Set 8 | otofuke
# Processing Record 4 of Set 8 | ouro preto do oeste
# Processing Record 5 of Set 8 | plettenberg bay
# Processing Record 6 of Set 8 | frontera
# Processing Record 7 of Set 8 | lorengau
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | tiarei
# Processing Record 10 of Set 8 | manavalakurichi
# Processing Record 11 of Set 8 | namatanai
# Processing Record 12 of Set 8 | nortelandia
# Processing Record 13 of Set 8 | merauke
# Processing Record 14 of Set 8 | north adams
# Processing Record 15 of Set 8 | libreville
# Processing Record 16 of Set 8 | ilulissat
# Processing Record 17 of Set 8 | la carlota
# Processing Record 18 of Set 8 | soligalich
# Processing Record 19 of Set 8 | luganville
# Processing Record 20 of Set 8 | zlynka
# Processing Record 21 of Set 8 | zhangjiakou
# Processing Record 22 of Set 8 | tiksi
# Processing Record 23 of Set 8 | chifeng
# Processing Record 24 of Set 8 | santa rosa
# Processing Record 25 of Set 8 | suifenhe
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | skibbereen
# Processing Record 28 of Set 8 | kuala lipis
# Processing Record 29 of Set 8 | makung
# City not found. Skipping... makung
# Processing Record 30 of Set 8 | faanui
# Processing Record 31 of Set 8 | ilovlya
# Processing Record 32 of Set 8 | pangoa
# Processing Record 33 of Set 8 | ontario
# Processing Record 34 of Set 8 | kang
# Processing Record 35 of Set 8 | old shinyanga
# Processing Record 36 of Set 8 | east london
# Processing Record 37 of Set 8 | katsuura
# Processing Record 38 of Set 8 | darab
# Processing Record 39 of Set 8 | copacabana
# Processing Record 40 of Set 8 | punta alta
# Processing Record 41 of Set 8 | porechye-rybnoye
# Processing Record 42 of Set 8 | edd
# Processing Record 43 of Set 8 | kibre mengist
# Processing Record 44 of Set 8 | tenenkou
# Processing Record 45 of Set 8 | alta floresta
# Processing Record 46 of Set 8 | tsuruga
# Processing Record 47 of Set 8 | sisimiut
# Processing Record 48 of Set 8 | marzuq
# Processing Record 49 of Set 8 | rexburg
# Processing Record 50 of Set 8 | urumqi
# Processing Record 1 of Set 9 | nikolskoye
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | broome
# Processing Record 4 of Set 9 | qaqortoq
# Processing Record 5 of Set 9 | asyut
# Processing Record 6 of Set 9 | victor harbor
# Processing Record 7 of Set 9 | lolua
# City not found. Skipping... lolua
# Processing Record 8 of Set 9 | mayo
# Processing Record 9 of Set 9 | teeli
# Processing Record 10 of Set 9 | malartic
# Processing Record 11 of Set 9 | payo
# Processing Record 12 of Set 9 | dalinghe
# City not found. Skipping... dalinghe
# Processing Record 13 of Set 9 | umzimvubu
# City not found. Skipping... umzimvubu
# Processing Record 14 of Set 9 | banjar
# Processing Record 15 of Set 9 | sanbu
# Processing Record 16 of Set 9 | laguna
# Processing Record 17 of Set 9 | satana
# Processing Record 18 of Set 9 | chernyshevskiy
# Processing Record 19 of Set 9 | talalayivka
# Processing Record 20 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping... yuzhno-yeniseyskiy
# Processing Record 21 of Set 9 | rawson
# Processing Record 22 of Set 9 | vanderhoof
# Processing Record 23 of Set 9 | panzhihua
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | serebryanyy bor
# Processing Record 26 of Set 9 | biak
# Processing Record 27 of Set 9 | baruun-urt
# Processing Record 28 of Set 9 | shimanovsk
# Processing Record 29 of Set 9 | padang
# Processing Record 30 of Set 9 | valleyview
# Processing Record 31 of Set 9 | halalo
# City not found. Skipping... halalo
# Processing Record 32 of Set 9 | porosozero
# Processing Record 33 of Set 9 | okha
# Processing Record 34 of Set 9 | dipkarpaz
# City not found. Skipping... dipkarpaz
# Processing Record 35 of Set 9 | taywarah
# Processing Record 36 of Set 9 | chimbote
# Processing Record 37 of Set 9 | lakes entrance
# Processing Record 38 of Set 9 | bajos de haina
# Processing Record 39 of Set 9 | lagos
# Processing Record 40 of Set 9 | marawi
# Processing Record 41 of Set 9 | bandarbeyla
# Processing Record 42 of Set 9 | genhe
# Processing Record 43 of Set 9 | krym
# Processing Record 44 of Set 9 | amahai
# Processing Record 45 of Set 9 | aquidauana
# Processing Record 46 of Set 9 | pacsa
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | babanusah
# City not found. Skipping... babanusah
# Processing Record 49 of Set 9 | ardmore
# Processing Record 50 of Set 9 | puerto madero
# Processing Record 1 of Set 10 | tapes
# Processing Record 2 of Set 10 | ugoofaaru
# Processing Record 3 of Set 10 | barwadih
# Processing Record 4 of Set 10 | erenhot
# Processing Record 5 of Set 10 | miri
# Processing Record 6 of Set 10 | dalvik
# Processing Record 7 of Set 10 | sunrise manor
# Processing Record 8 of Set 10 | palmer
# Processing Record 9 of Set 10 | kamenskoye
# City not found. Skipping... kamenskoye
# Processing Record 10 of Set 10 | polyarnyy
# Processing Record 11 of Set 10 | blanquefort
# Processing Record 12 of Set 10 | teneguiban
# City not found. Skipping... teneguiban
# Processing Record 13 of Set 10 | burkhala
# City not found. Skipping... burkhala
# Processing Record 14 of Set 10 | anadyr
# Processing Record 15 of Set 10 | manjacaze
# Processing Record 16 of Set 10 | tadine
# Processing Record 17 of Set 10 | gampaha
# Processing Record 18 of Set 10 | nizhniy kuranakh
# Processing Record 19 of Set 10 | charters towers
# Processing Record 20 of Set 10 | chaumont
# Processing Record 21 of Set 10 | gulbene
# Processing Record 22 of Set 10 | ozernovskiy
# Processing Record 23 of Set 10 | nadym
# Processing Record 24 of Set 10 | caboolture
# Processing Record 25 of Set 10 | san ciro de acosta
# Processing Record 26 of Set 10 | colesberg
# Processing Record 27 of Set 10 | zyryanka
# Processing Record 28 of Set 10 | halifax
# Processing Record 29 of Set 10 | sola
# Processing Record 30 of Set 10 | abu dhabi
# Processing Record 31 of Set 10 | mandali
# Processing Record 32 of Set 10 | geresk
# City not found. Skipping... geresk
# Processing Record 33 of Set 10 | norala
# Processing Record 34 of Set 10 | dunedin
# Processing Record 35 of Set 10 | usinsk
# Processing Record 36 of Set 10 | achisay
# City not found. Skipping... achisay
# Processing Record 37 of Set 10 | brazii
# Processing Record 38 of Set 10 | kharp
# Processing Record 39 of Set 10 | darnah
# Processing Record 40 of Set 10 | lasa
# Processing Record 41 of Set 10 | churapcha
# Processing Record 42 of Set 10 | morgan city
# Processing Record 43 of Set 10 | kpandae
# Processing Record 44 of Set 10 | hasaki
# Processing Record 45 of Set 10 | tisul
# Processing Record 46 of Set 10 | warqla
# City not found. Skipping... warqla
# Processing Record 47 of Set 10 | los llanos de aridane
# Processing Record 48 of Set 10 | ciudad bolivar
# Processing Record 49 of Set 10 | brooks
# Processing Record 50 of Set 10 | tevaitoa
# Processing Record 1 of Set 11 | atikokan
# Processing Record 2 of Set 11 | yumen
# Processing Record 3 of Set 11 | rio grande
# Processing Record 4 of Set 11 | sept-iles
# Processing Record 5 of Set 11 | taoudenni
# Processing Record 6 of Set 11 | akividu
# Processing Record 7 of Set 11 | barabinsk
# Processing Record 8 of Set 11 | kargasok
# Processing Record 9 of Set 11 | chicama
# Processing Record 10 of Set 11 | great yarmouth
# Processing Record 11 of Set 11 | college
# Processing Record 12 of Set 11 | gorodishche
# Processing Record 13 of Set 11 | adrar
# Processing Record 14 of Set 11 | san policarpo
# Processing Record 15 of Set 11 | malanje
# Processing Record 16 of Set 11 | kavaratti
# Processing Record 17 of Set 11 | harer
# Processing Record 18 of Set 11 | maniitsoq
# Processing Record 19 of Set 11 | notse
# Processing Record 20 of Set 11 | general roca
# Processing Record 21 of Set 11 | arcos de la frontera
# Processing Record 22 of Set 11 | fredericksburg
# Processing Record 23 of Set 11 | staryy nadym
# Processing Record 24 of Set 11 | ellensburg
# Processing Record 25 of Set 11 | timmins
# Processing Record 26 of Set 11 | inongo
# Processing Record 27 of Set 11 | san isidro
# Processing Record 28 of Set 11 | yafran
# Processing Record 29 of Set 11 | fort saint john
# City not found. Skipping... fort saint john
# Processing Record 30 of Set 11 | viedma
# Processing Record 31 of Set 11 | klyuchi
# Processing Record 32 of Set 11 | ratnagiri
# Processing Record 33 of Set 11 | qafsah
# City not found. Skipping... qafsah
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | bereda
# Processing Record 36 of Set 11 | bur gabo
# City not found. Skipping... bur gabo
# Processing Record 37 of Set 11 | jacksonville beach
# Processing Record 38 of Set 11 | praya
# Processing Record 39 of Set 11 | ingham
# Processing Record 40 of Set 11 | port-gentil
# Processing Record 41 of Set 11 | burnie
# Processing Record 42 of Set 11 | marcona
# City not found. Skipping... marcona
# Processing Record 43 of Set 11 | bara
# Processing Record 44 of Set 11 | ginir
# Processing Record 45 of Set 11 | panuco
# Processing Record 46 of Set 11 | vila franca do campo
# Processing Record 47 of Set 11 | monreal
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | pacific grove
# Processing Record 50 of Set 11 | samarai
# Processing Record 1 of Set 12 | dong xoai
# Processing Record 2 of Set 12 | veraval
# Processing Record 3 of Set 12 | novyy urengoy
# Processing Record 4 of Set 12 | mastic beach
# Processing Record 5 of Set 12 | totma
# Processing Record 6 of Set 12 | elk river
# Processing Record 7 of Set 12 | westport
# Processing Record 8 of Set 12 | coihaique
# Processing Record 9 of Set 12 | les cayes
# Processing Record 10 of Set 12 | kasane
# Processing Record 11 of Set 12 | alice springs
# Processing Record 12 of Set 12 | aneho
# Processing Record 13 of Set 12 | margate
# Processing Record 14 of Set 12 | pachperwa
# Processing Record 15 of Set 12 | montelibano
# Processing Record 16 of Set 12 | vigrestad
# Processing Record 17 of Set 12 | partur
# Processing Record 18 of Set 12 | presidencia roque saenz pena
# Processing Record 19 of Set 12 | dhidhdhoo
# Processing Record 20 of Set 12 | senneterre
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | vanimo
# Processing Record 23 of Set 12 | kenai
# Processing Record 24 of Set 12 | nelson bay
# Processing Record 25 of Set 12 | trairi
# Processing Record 26 of Set 12 | zhengjiatun
# Processing Record 27 of Set 12 | san jose de los arroyos
# City not found. Skipping... san jose de los arroyos
# Processing Record 28 of Set 12 | bafq
# Processing Record 29 of Set 12 | agdas
# Processing Record 30 of Set 12 | dingle
# Processing Record 31 of Set 12 | najran
# Processing Record 32 of Set 12 | trelew
# Processing Record 33 of Set 12 | xuanhua
# Processing Record 34 of Set 12 | manga
# Processing Record 35 of Set 12 | tecoanapa
# Processing Record 36 of Set 12 | bambanglipuro
# Processing Record 37 of Set 12 | kangaatsiaq
# Processing Record 38 of Set 12 | marabba
# Processing Record 39 of Set 12 | roald
# Processing Record 40 of Set 12 | elat
# Processing Record 41 of Set 12 | weesp
# Processing Record 42 of Set 12 | izhma
# Processing Record 43 of Set 12 | atambua
# Processing Record 44 of Set 12 | sorvag
# City not found. Skipping... sorvag
# Processing Record 45 of Set 12 | shaowu
# Processing Record 46 of Set 12 | simpang
# Processing Record 47 of Set 12 | kasulu
# Processing Record 48 of Set 12 | tomatlan
# Processing Record 49 of Set 12 | corumba
# Processing Record 50 of Set 12 | tutoia
# Processing Record 1 of Set 13 | vereeniging
# Processing Record 2 of Set 13 | adyge-khabl
# Processing Record 3 of Set 13 | anchorage
# Processing Record 4 of Set 13 | goundam
# Processing Record 5 of Set 13 | pinerolo
# Processing Record 6 of Set 13 | mecca
# Processing Record 7 of Set 13 | kokopo
# Processing Record 8 of Set 13 | odweyne
# Processing Record 9 of Set 13 | parana
# Processing Record 10 of Set 13 | mabaruma
# Processing Record 11 of Set 13 | olga
# Processing Record 12 of Set 13 | boyolangu
# Processing Record 13 of Set 13 | isla mujeres
# Processing Record 14 of Set 13 | mandleshwar
# Processing Record 15 of Set 13 | qingyuan
# Processing Record 16 of Set 13 | arnedo
# Processing Record 17 of Set 13 | cap malheureux
# Processing Record 18 of Set 13 | chardara
# Processing Record 19 of Set 13 | karpogory
# Processing Record 20 of Set 13 | linxia
# Processing Record 21 of Set 13 | krasnoturansk
# Processing Record 22 of Set 13 | kulhudhuffushi
# Processing Record 23 of Set 13 | pemangkat
# Processing Record 24 of Set 13 | gimli
# Processing Record 25 of Set 13 | mount gambier
# Processing Record 26 of Set 13 | hay river
# Processing Record 27 of Set 13 | high prairie
# Processing Record 28 of Set 13 | katangli
# Processing Record 29 of Set 13 | svetlogorsk
# Processing Record 30 of Set 13 | korem
# Processing Record 31 of Set 13 | cairns
# Processing Record 32 of Set 13 | radnevo
# Processing Record 33 of Set 13 | tumannyy
# City not found. Skipping... tumannyy
# Processing Record 34 of Set 13 | mezokeresztes
# Processing Record 35 of Set 13 | faya
# Processing Record 36 of Set 13 | timizart
# Processing Record 37 of Set 13 | las tunas
# Processing Record 38 of Set 13 | seminole
# Processing Record 39 of Set 13 | vershino-shakhtaminskiy
# Processing Record 40 of Set 13 | bunia
# Processing Record 41 of Set 13 | jogindarnagar
# Processing Record 42 of Set 13 | thinadhoo
# Processing Record 43 of Set 13 | surin
# Processing Record 44 of Set 13 | morris
# Processing Record 45 of Set 13 | cumaribo
# City not found. Skipping... cumaribo
# Processing Record 46 of Set 13 | mogeiro
# Processing Record 47 of Set 13 | venado tuerto
# Processing Record 48 of Set 13 | westonaria
# Processing Record 49 of Set 13 | perehonivka
# Processing Record 50 of Set 13 | san lazaro
# Processing Record 1 of Set 14 | yanam
# Processing Record 2 of Set 14 | sulangan
# Processing Record 3 of Set 14 | abonnema
# Processing Record 4 of Set 14 | hasanabad
# Processing Record 5 of Set 14 | kitale
# Processing Record 6 of Set 14 | mogadishu
# Processing Record 7 of Set 14 | shenjiamen
# Processing Record 8 of Set 14 | warwick
# Processing Record 9 of Set 14 | filadelfia
# Processing Record 10 of Set 14 | komsomolskiy
# Processing Record 11 of Set 14 | deputatskiy
# Processing Record 12 of Set 14 | teguldet
# Processing Record 13 of Set 14 | byron bay
# Processing Record 14 of Set 14 | aksarka
# Processing Record 15 of Set 14 | antofagasta
# Processing Record 16 of Set 14 | mao
# Processing Record 17 of Set 14 | athabasca
# Processing Record 18 of Set 14 | limoux
# Processing Record 19 of Set 14 | port antonio
# Processing Record 20 of Set 14 | lebyazhye
# Processing Record 21 of Set 14 | huilong
# Processing Record 22 of Set 14 | yei
# Processing Record 23 of Set 14 | tuatapere
# Processing Record 24 of Set 14 | barbar
# City not found. Skipping... barbar
# Processing Record 25 of Set 14 | klamath falls
# Processing Record 26 of Set 14 | inhambane
# Processing Record 27 of Set 14 | grindavik
# Processing Record 28 of Set 14 | dosso
# Processing Record 29 of Set 14 | tudela
# Processing Record 30 of Set 14 | marsa matruh
# Processing Record 31 of Set 14 | bacalar
# Processing Record 32 of Set 14 | estelle
# Processing Record 33 of Set 14 | isla vista
# Processing Record 34 of Set 14 | waddan
# Processing Record 35 of Set 14 | rybnaya sloboda
# Processing Record 36 of Set 14 | ballina
# Processing Record 37 of Set 14 | wunsiedel
# Processing Record 38 of Set 14 | springfield
# Processing Record 39 of Set 14 | tres arroyos
# Processing Record 40 of Set 14 | ormara
# Processing Record 41 of Set 14 | somotillo
# Processing Record 42 of Set 14 | houma
# Processing Record 43 of Set 14 | purpe
# Processing Record 44 of Set 14 | belaya gora
# Processing Record 45 of Set 14 | aykhal
# Processing Record 46 of Set 14 | bilma
# Processing Record 47 of Set 14 | mindelo
# Processing Record 48 of Set 14 | nanhai
# Processing Record 49 of Set 14 | hun
# Processing Record 50 of Set 14 | krasnoselkup
# Processing Record 1 of Set 15 | alekseyevka
# Processing Record 2 of Set 15 | avera
# Processing Record 3 of Set 15 | port blair
# Processing Record 4 of Set 15 | tono
# Processing Record 5 of Set 15 | impfondo
# Processing Record 6 of Set 15 | talcahuano
# Processing Record 7 of Set 15 | gorontalo
# Processing Record 8 of Set 15 | gasa
# Processing Record 9 of Set 15 | scottsburgh
# City not found. Skipping... scottsburgh
# Processing Record 10 of Set 15 | phibun mangsahan
# Processing Record 11 of Set 15 | ringebu
# Processing Record 12 of Set 15 | la ronge
# Processing Record 13 of Set 15 | lixourion
# Processing Record 14 of Set 15 | buin
# Processing Record 15 of Set 15 | pucallpa
# Processing Record 16 of Set 15 | krupina
# Processing Record 17 of Set 15 | deniliquin
# Processing Record 18 of Set 15 | santa isabel do rio negro
# Processing Record 19 of Set 15 | miandrivazo
# Processing Record 20 of Set 15 | aklavik
# Processing Record 21 of Set 15 | pokaran
# Processing Record 22 of Set 15 | caravelas
# Processing Record 23 of Set 15 | yoichi
# Processing Record 24 of Set 15 | zhigansk
# Processing Record 25 of Set 15 | madanapalle
# Processing Record 26 of Set 15 | saba
# Processing Record 27 of Set 15 | meulaboh
# Processing Record 28 of Set 15 | matamoros
# Processing Record 29 of Set 15 | balkanabat
# Processing Record 30 of Set 15 | walldorf
# Processing Record 31 of Set 15 | mercedes
# Processing Record 32 of Set 15 | alamosa
# Processing Record 33 of Set 15 | nova ushytsya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 672

# %%
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Carupano      VE  10.6678  -63.2585     77.83        89          96
# 1           Avarua      CK -21.2078 -159.7750     73.45        68          75
# 2       Butaritari      KI   3.0707  172.7902     81.50        72           7
# 3           Hobart      AU -42.8794  147.3294     49.86        80          90
# 4       Manjeshwar      IN  12.7194   74.8861     79.75        87          87
# 5             Nuuk      GL  64.1835  -51.7216     25.41        42          20
# 6  Haines Junction      CA  60.7522 -137.5108      8.55        92         100
# 7            Airai      TL  -8.9266  125.4092     62.24        91          79
# 8         Berlevag      NO  70.8578   29.0864     22.95        74          20
# 9        Busselton      AU -33.6500  115.3333     44.04        67          59
#
#    Wind Speed Current Description
# 0        8.93     overcast clouds
# 1        9.22       broken clouds
# 2        4.14           clear sky
# 3        1.99     overcast clouds
# 4        4.34       moderate rain
# 5       19.57                sand
# 6        1.14     overcast clouds
# 7        0.43       broken clouds
# 8        9.22                snow
# 9        6.15       broken clouds

# %%
output_data_file='WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
